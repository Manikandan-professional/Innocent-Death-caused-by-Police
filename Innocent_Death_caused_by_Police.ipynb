# %% [markdown]
# <a href="https://colab.research.google.com/github/Manikandan-professional/Innocent-Death-caused-by-Police/blob/main/Innocent_Death_caused_by_Police.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Innocent-Death-caused-by-Police**

# %% [markdown]
# **Importing the Necessary Moduels**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Reading the csv file**

# %%
a=pd.read_csv('https://raw.githubusercontent.com/Manikandan-professional/Innocent-Death-caused-by-Police/main/Innocent%20Deaths%20caused%20by%20Police%20(All%20time).csv')
a
# Out:
#        Unique ID  ... Foreknowledge of mental illness
# 0          25747  ...                              No
# 1          25748  ...                              No
# 2          25746  ...                              No
# 3          25749  ...                              No
# 4              1  ...                              No
# ...          ...  ...                             ...
# 30855      30856  ...                              No
# 30856      30857  ...                              No
# 30857      30858  ...                              No
# 30858      30859  ...                              No
# 30859      30860  ...                              No
#
# [30860 rows x 27 columns]

# %% [markdown]
# **Conversion of csv file to DataFrame**

# %%
df=pd.DataFrame(a)

# %% [markdown]
# **First five row preview of the loaded dataset**

# %%
df.head()
# Out:
#    Unique ID  ... Foreknowledge of mental illness
# 0      25747  ...                              No
# 1      25748  ...                              No
# 2      25746  ...                              No
# 3      25749  ...                              No
# 4          1  ...                              No
#
# [5 rows x 27 columns]

# %% [markdown]
# **Columns in the DataFrame(df)**

# %%
list(df.columns)
# Out:
# ['Unique ID',
#  'Name',
#  'Age',
#  'Gender',
#  'Race',
#  'URL of image',
#  ' Date of injury resulting in death (month/day/year)',
#  'Location of injury (address)',
#  'Location of death (city)',
#  'State',
#  'Location of death (zip code)',
#  'Location of death (county)',
#  'Full Address',
#  'Latitude',
#  'Longitude',
#  'Agency or agencies involved',
#  'Highest level of force',
#  'Alleged weapon',
#  'Aggressive physical movement',
#  'Fleeing/Not fleeing',
#  'Description Temp',
#  'URL Temp',
#  'Brief description',
#  'Dispositions/Exclusions INTERNAL USE, NOT FOR ANALYSIS',
#  'Intended use of force (Developing)',
#  'Supporting document link',
#  'Foreknowledge of mental illness']

# %%
df.isnull().sum()
# Out:
# Unique ID                                                     0
# Name                                                          0
# Age                                                        1172
# Gender                                                      136
# Race                                                          0
# URL of image                                              16505
#  Date of injury resulting in death (month/day/year)           0
# Location of injury (address)                                554
# Location of death (city)                                     38
# State                                                         0
# Location of death (zip code)                                185
# Location of death (county)                                   15
# Full Address                                                  0
# Latitude                                                      0
# Longitude                                                     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30860 entries, 0 to 30859
# Data columns (total 27 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Unique ID                                               30860 non-null  int64
#  1   Name                                                    30860 non-null  object
#  2   Age                                                     29688 non-null  object
#  3   Gender                                                  30724 non-null  object
#  4   Race                                                    30860 non-null  object
#  5   URL of image                                            14355 non-null  object
#  6    Date of injury resulting in death (month/day/year)     30860 non-null  object
#  7   Location of injury (address)                            30306 non-null  object
# ...

# %%
print(list(a.columns))
print(len(list(a.columns)))
# Out:
# ['Unique ID', 'Name', 'Age', 'Gender', 'Race', 'URL of image', ' Date of injury resulting in death (month/day/year)', 'Location of injury (address)', 'Location of death (city)', 'State', 'Location of death (zip code)', 'Location of death (county)', 'Full Address', 'Latitude', 'Longitude', 'Agency or agencies involved', 'Highest level of force', 'Alleged weapon', 'Aggressive physical movement', 'Fleeing/Not fleeing', 'Description Temp', 'URL Temp', 'Brief description', 'Dispositions/Exclusions INTERNAL USE, NOT FOR ANALYSIS', 'Intended use of force (Developing)', 'Supporting document link', 'Foreknowledge of mental illness']
# 27
